# %%
from tensorflow.keras.models import load_model

h5_path = "C:/Users/navya/Downloads/model_weights.pkl"

try:
    model = load_model(h5_path)
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: File format not supported: filepath=C:/Users/navya/Downloads/model_weights.pkl. Keras 3 only supports V3 `.keras` files and legacy H5 format files (`.h5` extension). Note that the legacy SavedModel format is not supported by `load_model()` in Keras 3. In order to reload a TensorFlow SavedModel as an inference-only layer in Keras 3, use `keras.layers.TFSMLayer(C:/Users/navya/Downloads/model_weights.pkl, call_endpoint='serving_default')` (note that your `call_endpoint` might have a different name).

# %%
import magic

pkl_path = "C:/Users/navya/Downloads/model_weights.pkl"
file_type = magic.from_file(pkl_path, mime=True)

print(f"File type detected: {file_type}")
# Out:
# File type detected: application/octet-stream

# %%
import pickle

pkl_path = "C:/Users/navya/Downloads/model_weights.pkl"

try:
    with open(pkl_path, "rb") as f:
        data = pickle.load(f)
    print("✅ Successfully loaded as a Pickle file!")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ❌ Error: invalid load key, '\x09'.

# %%
pkl_path = "C:/Users/navya/Downloads/model_weights.pkl"

with open(pkl_path, "rb") as f:
    header = f.read(10)  # Read first 10 bytes

print(f"File header: {header}")
# Out:
# File header: b'\x80\x04\x95\xdb\x00\x00\x00\x00\x00\x00'

# %%
import joblib

try:
    weights = joblib.load(pkl_path)
    print("✅ Successfully loaded with joblib!")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ✅ Successfully loaded with joblib!

# %%
import joblib
import h5py
import numpy as np

pkl_path = "C:/Users/navya/Downloads/model_weights.pkl"
h5_path = "C:/Users/navya/Downloads/model_weights.h5"

# Load weights from .pkl file
weights = joblib.load(pkl_path)

# Save weights to .h5 format
with h5py.File(h5_path, "w") as hf:
    for i, w in enumerate(weights):
        hf.create_dataset(f"weight_{i}", data=np.array(w))

print("✅ Weights successfully converted to HDF5 (.h5) format!")
# Out:
# ✅ Weights successfully converted to HDF5 (.h5) format!

# %%
import joblib

pkl_path = "C:/Users/navya/Downloads/model_weights.pkl"
weights = joblib.load(pkl_path)

print(type(weights))  # Should be a list or dictionary
print(len(weights))   # Number of layers (if applicable)
print(weights.keys() if isinstance(weights, dict) else "Not a dict")
# Out:
# <class 'list'>
# 12
# Not a dict

# %%
import joblib
import h5py
import numpy as np

pkl_path = "C:/Users/navya/Downloads/model_weights.pkl"
h5_path = "C:/Users/navya/Downloads/model_weights.h5"

# Load weights from the .pkl file
weights = joblib.load(pkl_path)

# Save as HDF5 file
with h5py.File(h5_path, "w") as hf:
    for i, w in enumerate(weights):
        hf.create_dataset(f"layer_{i}", data=np.array(w))

print("✅ Weights successfully converted to .h5 format!")
# Out:
# ✅ Weights successfully converted to .h5 format!

# %%
h5_path = "C:/Users/navya/Downloads/model_weights.weights.h5"

# %%
model.save_weights(h5_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.save_weights(h5_path)
#
# NameError: name 'model' is not defined

# %%
model.load_weights("C:/Users/navya/Downloads/model_weights.weights.h5")

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.models import model_from_json

# Define paths
json_path = "C:/Users/navya/Downloads/model_architecture.json"
weights_path = "C:/Users/navya/Downloads/model_weights.weights.h5"
# Load the model
with open(json_path, "r") as json_file:
    model_json = json_file.read()
model = model_from_json(model_json)
model.load_weights(weights_path)
print("✅ Model loaded successfully!")

# Load Haar cascade for face detection
haar_cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
if not os.path.exists(haar_cascade_path):
    raise FileNotFoundError(f"\U0000274C Haarcascade file not found: {haar_cascade_path}")
face_cascade = cv2.CascadeClassifier(haar_cascade_path)

# Define emotion labels
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        print("\U0000274C Failed to capture image")
        break
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))
    
    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (48, 48))
        roi_gray = np.expand_dims(roi_gray, axis=-1)
        roi_gray = np.expand_dims(roi_gray, axis=0)
        roi_gray = roi_gray / 255.0
        
        prediction = model.predict(roi_gray)
        emotion_label = emotions[np.argmax(prediction)]
        
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        cv2.putText(frame, emotion_label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
    
    cv2.imshow('Emotion Detection', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ✅ Model loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# ...

# %%
import cv2
cap = cv2.VideoCapture(0)
ret, frame = cap.read()
print(ret, type(frame))  # Should print True and <class 'numpy.ndarray'>
# Out:
# True <class 'numpy.ndarray'>

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.11.0

# %%
import os

json_path = "C:/Users/navya/Downloads/model.json"
print("Checking if model.json exists...")

if os.path.exists(json_path):
    print("✅ Found:", json_path)
else:
    print("❌ Not Found! Available files in Downloads:", os.listdir("C:/Users/navya/Downloads/"))
# Out:
# Checking if model.json exists...
# ...

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(classification_report)
cm = confusion_matrix
print("\nConfusion Matrix:")
print(cm)
# Out:
# <function classification_report at 0x0000022193974CC0>
#
# Confusion Matrix:
# <function confusion_matrix at 0x000002219394F920>
